# %% [markdown]
# # <center>Web Scraping (2): Dyamic Web Pages by *Playwright*</center>
#
# References:
# - https://playwright.dev/python/docs/intro
# - https://oxylabs.io/blog/playwright-web-scraping

# %% [markdown]
# <h2> A big picture</h2>
#
# <img src = "https://python.langchain.com/v0.1/assets/images/web_scraping-001e2279b9e46c696012ac26d7f218a2.png" width="80%">
#
# source: https://python.langchain.com/v0.1/docs/use_cases/web_scraping/

# %% [markdown]
# ## 1. Why Playwright
# - So far, we have learned how to scrape **static** HTML pages using **Requests + BeautifulSoup**
# - However, if the web content relies on **javascript or AJAX** to build the content, this combination does not work
#   - Elements in a web page loaded **asynchronously**
#      * while requests.get(url) can only return the initial content
#      * you may need to wait for a while to get web content fully loaded
#   - You need to **interact with the page** to get some content loaded, e.g.
#      * scroll down to load more
#      * click a button like "more"
#      * fill a form
# - Example: https://www.quora.com/topic/Machine-Learning

# %%
# Exercise 1.1. Scape quora page using requests+beautifulsoup

# import requests package
import requests                   

# import BeautifulSoup from package bs4 (i.e. beautifulsoup4)
from bs4 import BeautifulSoup   

page = requests.get("https://www.quora.com/topic/Machine-Learning")    # send a get request to the web page

if page.status_code==200:      

    soup = BeautifulSoup(page.content, 'html.parser')
    
    # get all questions
    questions=soup.select("span.q-box.qu-userSelect--text")
    
    for i, q in enumerate(questions):
        print(i, q.get_text())
        print("\n")
    
# Note: nothing is returned. Do you know why?

# %% [markdown]
# ## 2. Playwright
# - Playwright is a **Web automation framework** that can automate web browser interactions. It can navigate to URLs, enter text, click buttons, extract text, etc. The most exciting feature of Playwright is that it can work with multiple pages at the same time, without getting blocked or having to wait for operations to complete in any of them.
# - It supports **asychronous** functions, which can work with multiple pages at the same time, without getting blocked or having to wait for operations to complete in any of them.
# - It supports most browsers such as Google Chrome, Microsoft Edge using Chromium, Firefox and Safari with a single web driver (Selenium has a separate web driver for each browsser).
# - Playwright is really useful when you have to perform action on a website such as:
#   - clicking on buttons
#   - filling forms
#   - scrolling
#   - taking a screenshot
#   - execute Javascript code.
# - Installation: `pip install playwright`
# - For more details, check:
#     - https://playwright.dev/python/docs/intro
#     - https://oxylabs.io/blog/playwright-web-scraping

# %% [markdown]
# ## 3. Use of Playwright for Scraping

# %% [markdown]
# ### 3.1. **Navigating**
# - Navigate to a link: Similar to beautifulsoup, but using different syntax
# - Find elements by id, name, xpath, CSS selectors
#     - For more details, check https://playwright.dev/python/docs/api/class-locator
#     * Note **query_selector()** vs. **fquery_selector<font color='red'>_all</font>()**
#         - *query_selector*: collect the first elements by a CSS selector
#         - *query_selector_all*: collect the first elements by a CSS selector
#
# |    | requests/BeautifulSoup | Selenium WebDriver |
# | -- |:------------------      |:-----------|
# | Navigate to a link |   `requests.get(url)`           | `page.goto(url)`    |
# | find elements  | `soup.select()` | `page.query_selector("p")`<br>`page.query_selector_all("p")`|
# | get attributes of <br>element (say `p`) | `p.attrs` <br>    `p["class"]` | `p.get_attribute("class")` |
# | get text | `p.get_text()` | `p.inner_text()`  or `p.text_content()`|

# %% [markdown]
# - **Headless browser** :
#     - A web browser without a graphical user interface (GUI), i.e., `playwright.firefox.launch(headless=True)`
#     - During web scraping there is often no need to start a website. Web scraping with a headless browser allows quickly navigating websites and collecting public data
# - **`Sync` vs. `Async`**:
#     - Although Playwright provides both `Sync` and `Async` APIs, since Jupyter notebooks use an asyncio event loop, we need to use Playwright's async API as well.
#     - Async IO is a single-threaded, single-process design, but uses cooperative multitasking. It is designed for IO-bound tasks.
#     - For details about `Sync` and `Async` APIs, please read https://realpython.com/async-io-python/
# - **Asychronous (async/await syntax)**:
#     - The **async** keyword is used to define a coroutine function, which can be suspended and resumed at specific points during its execution.
#     - The **await** keyword is used to indicate that a coroutine function should pause execution until a certain event occurs

# %%
import asyncio
from playwright.async_api import async_playwright

# Use Playwright async API
async with async_playwright() as playwright:
    
    # Launch Firefox in non-headless mode (visible UI)
    browser = await playwright.firefox.launch(headless=False)
    
    # For chrom browser, use the following
    #browser = playwright.chromium.launch(headless=False)
    
    # Open a new browser page with specified dimensions
    page = await browser.new_page()
    
    # Navigate to the given URL
    await page.goto("https://www.quora.com/topic/Machine-Learning")
    
    # Wait for 5 seconds so that the page can loaded
    await asyncio.sleep(5)
    
    await browser.close()

# %% [markdown]
# ### 3.2 Locating and Scraping Elements
#
#
# For details of locator, see https://playwright.dev/docs/other-locators#introduction

# %%
# Use Playwright async API
async with async_playwright() as playwright:
    
    # Launch Firefox in non-headless mode (visible UI)
    browser = await playwright.firefox.launch(headless=False)
    
    # For chrom browser, use the following
    #browser = playwright.chromium.launch(headless=False)
    
    # Open a new browser page with specified dimensions
    page = await browser.new_page()
    
    # Navigate to the given URL
    await page.goto("https://www.quora.com/topic/Machine-Learning")
    
    # wait until page has been loaded
    await asyncio.sleep(5)
    
    # query all elements by CSS selector
    all_questions = await page.query_selector_all('span.q-box.qu-userSelect--text')
    
    # Collect the elements
    qs =[]
    for i, q in enumerate(all_questions):

        # query the span element under each question
        q = await q.query_selector('span')

        # get the text
        text = await q.inner_text()
        
        print(f"{i}:  {text}\n")
        
        qs.append(text)

    await browser.close()
# Out:
# 0:  What is your opinion of DeepSeek vs other US LLMs in terms of intellectual capital, Nvidia, and the efficacy of export bans in the West vs China battleground?
#
# 1:  Why is everyone so obsessed with AI? What is it actually going to provide in the future?
#
# 2:  You can train any 8 year old kid to drive well. Why is it taking years and the full might of supercomputer AI to get a computer to do it?
#
# 3:  How do publishing platforms detect AI-generated content in books?
#
# 4:  How do Americans feel knowing about deep seek and chat GPT?
#
# 5:  Will AI replace programmers?
#
# 6:  What are the best sites for learning Data Science?
#
# 7:  What is the Candy AI app?
#
# 8:  Will AI replace programmers?
#
# 9:  How should software engineers prepare for the possibility of getting replaced by AI by 2025?

# %% [markdown]
# ### 3.3. Simulates users' actions performed in a web browser.
#
#   - click a button
#     * e.g. submit_button.click()
#   - fill a form
#     * e.g. text_box.fill("enter some text")
#   - scroll page down or up
#     * e.g. page.keyboard.down('End')
#   ...
#   - For details see https://playwright.dev/python/docs/input

# %% [markdown]
# **Click a link**
#
#
# Click "more" link to expand the full text

# %%
async with async_playwright() as playwright:
    
    # Launch Firefox in non-headless mode (visible UI)
    browser = await playwright.firefox.launch(headless=False)
    
    # For chrom browser, use the following
    #browser = playwright.chromium.launch(headless=False)
    
    # Open a new browser page with specified dimensions
    page = await browser.new_page()
    
    # Navigate to the given URL
    await page.goto("https://www.quora.com/topic/Machine-Learning")
    
    # wait until page has been loaded
    await asyncio.sleep(5)
    
    # locate the first "more" link
    more = await page.query_selector("div.q-text.qu-cursor--pointer.qt_read_more")
    
    # click the link
    await more.click()
    
    # wait for 5 seconds so that the content can be loaded
    await asyncio.sleep(5)
    
    await browser.close()

# %% [markdown]
# **Scroll down**
#
#
# Scroll down the page for 5 times to collect more questions

# %%
async with async_playwright() as playwright:
    
    # Launch Firefox in non-headless mode (visible UI)
    browser = await playwright.firefox.launch(headless=False)

    # For chrom browser, use the following
    #browser = playwright.chromium.launch(headless=False)

    # Open a new browser page with specified dimensions
    page = await browser.new_page()

    # Navigate to the given URL
    await page.goto("https://www.quora.com/topic/Machine-Learning")

    # wait until page has been loaded
    await asyncio.sleep(5)

    # scroll down 5 times
    for i in range(5):

        await page.evaluate("window.scrollTo(0, document.body.scrollHeight);")

        # wait for the content to be loaded
        await asyncio.sleep(2)   
    
    # query all elements by CSS selector
    all_questions = await page.query_selector_all('span.q-box.qu-userSelect--text')
        
    qs =[]
    for i, q in enumerate(all_questions):

        # query the span element under each question
        q = await q.query_selector('span')

        # get the text
        text = await q.inner_text()
        
        print(f"{i}:  {text}\n")
        
        qs.append(text)
        
await browser.close()
# Out:
# 0:  What is your opinion of DeepSeek vs other US LLMs in terms of intellectual capital, Nvidia, and the efficacy of export bans in the West vs China battleground?
#
# 1:  Why is everyone so obsessed with AI? What is it actually going to provide in the future?
#
# 2:  You can train any 8 year old kid to drive well. Why is it taking years and the full might of supercomputer AI to get a computer to do it?
#
# 3:  How do publishing platforms detect AI-generated content in books?
#
# 4:  How do Americans feel knowing about deep seek and chat GPT?
#
# 5:  Will AI replace programmers?
#
# 6:  What are the best sites for learning Data Science?
#
# 7:  What is the Candy AI app?
#
# 8:  Will AI replace programmers?
#
# 9:  How should software engineers prepare for the possibility of getting replaced by AI by 2025?
#
# 10:  What is the best AI image generator?
#
# 11:  How do I change my hairstyle naturally with AI?
#
# 12:  Are AIs prone to being fearful and therefore wanting to own firearms like many fearful American humans?
#
# 13:  How does 'unfiltered AI' differ from regular AI?
#
# 14:  Can the AI adapt to user behavior over time?
#
# 15:  Will the startup Chinese AI engine DeepSeek overtake ChatGPT?
#
# 16:  How do I re detect faces in Google photos?
#
# 17:  What are examples of AI rewriting the Bible?
#
# 18:  How well does X's Grok summarize your contribution if you frequently use X (formerly Twitter)?
#
# 19:  Can the AI adapt to user behavior over time?
#
# 20:  Why do AI-generated images have bad text and faces?
#
# 21:  Do programmers, programming, machine learning, neural networks, artificial intelligence or robotics love wild animals, domestic animals, cats, kittens, dogs, puppies, etc.?
#
# 22:  Is OpenAI's new model O3 approaching AGI?
#
# 23:  What are some commonly used deep learning models? Which one would you suggest for someone new to deep neural networks (DNNs)?
#
# 24:  How quickly will humans run out of human-generated data to train AI models like ChatGPT?
#
# 25:  What are the best books about data science?
#
# 26:  The US has Chatgpt, Meta AI, and Gemini. China has Deepseek AI. What does India have in the AI field, or where do we Indians realistically stand as of today?
#
# 27:  Can an AI generate a side view of a person's face when given a photo of said person's face?
#
# 28:  How can the PiDog robot dog learn to recognize faces?
#
# 29:  Is there an AI tool that can help you to predict games accurately?
#
# 30:  What do you think Lyrak's AI engine—as well as user-generated AI characters—will look like when they launch in May?
#
# 31:  Why are Chinese characters so ugly and primitive? Can you read 50,000 ugly characters? Did AI generate the Chinese characters?
#
# 32:  Why is it considered an offense to train an artificial intelligence on the output of another AI? If something is published, can anyone then read it?
#
# 33:  What are the benefits of using AI in video editing?
#
# 34:  What would happen if you matched 2 advanced AIS played against each other on the game of League of Legends with the same character?
#
# 35:  What is artificial intelligence?
#
# 36:  How do natural language processing models like BERT handle data that contains words from multiple languages?
#
# 37:  How can AI algorithms create game scenarios and characters, potentially replacing human game developers in certain aspects of game creation?
#
# 38:  What role does artificial intelligence play in making virtual simulations more immersive and adaptive to user behavior?
#
# 39:  How realistic are AI girlfriend chatbots today？?
#
# 40:  What is optical character recognition? What is its relationship to convolutional neural networks (CNNs) in machine learning and artificial intelligence (AI)?
#
# 41:  How can I publish a high-quality machine learning paper with real innovation? Using only XGBoost for predictions feels too basic. How can I make my work stand out for a high impact journal?
#
# 42:  How well does X's Grok summarize your contribution if you frequently use X (formerly Twitter)?
#
# 43:  Are highly expensive Nvidia AI chips doomed after the release of highly cheap, efficient and open source Chinese Deepseek AI models?
#
# 44:  How can I pass an exam with valid Professional-Machine-Learning-engineer PDF dumps?
#
# 45:  How can generative adversarial networks (GANs) be countered using HPC?
#
# 46:  How do you think DeepSeek's AI reasoning model R1, which was published fully open-source and sparked a sell-off in US tech stocks, will impact the AI industry?
#
# 47:  Is it possible for AI to become so advanced that it becomes difficult to distinguish between real people and computer-generated characters in media? If so, when do experts predict this may happen?
#
# 48:  What is the number of parameters in a transformer-based language model like BERT or T5?
#
# 49:  Is it possible to easily identify AI profiles accurately on Instagram and Facebook without any annotation whatsoever?
#
# 50:  What role does artificial intelligence play in making virtual simulations more immersive and adaptive to user behavior?
#
# 51:  Is there an app that can detect your age from your face (facial recognition)?
#
# 52:  The US has Chatgpt, Meta AI, and Gemini. China has Deepseek AI. What does India have in the AI field, or where do we Indians realistically stand as of today?
#
# 53:  What are the hot topics in artificial intelligence for research?
#
# 54:  What does AI code look like?
#
# 55:  Is computer programming a dying career? Is computer programming a career that's likely to be automated out of existence sooner than most others?
#
# 56:  Do programmers, programming, machine learning, neural networks, artificial intelligence or robotics love wild animals, domestic animals, cats, kittens, dogs, puppies, etc.?
#
# 57:  What are the best sites for learning Data Science?
#
# 58:  Do programmers, programming, machine learning, neural networks, artificial intelligence or robotics love wild animals, domestic animals, cats, kittens, dogs, puppies, etc.?
#
# 59:  How do you think the ability to create user-generated AI characters for calls can enhance language learning and interview practice?
#
# 60:  How do I learn machine learning?
#
# 61:  Why is it considered an offense to train an artificial intelligence on the output of another AI? If something is published, can anyone then read it?
#
# 62:  Is it possible to illustrate entire novels/book series (such as The Lord Of The Rings and the Harry Potter books) using AI text-to-image generators such as Midjourney, with default image parameters set for all characters and sceneries in these books?
#
# 63:  With so many chips being described as "AI hardware" these days, would they be any good for creating better more realistic in-game characters, or are they merely for ChatGPT-like chatbots?
#
# 64:  How can AI-powered SaaS platforms predict user behavior?
#
# 65:  What are examples of AI rewriting the Bible?
#
# 66:  Is it possible to create video game characters that think and feel with AI?
#
# 67:  Which AI models are most effective at generating lifelike characters in storytelling?
#
# 68:  What are the best model, steps and simulator for AI for creating photorealistic human photos? I am now using Euler with Juggernaut model on image to do character to image.
#
# 69:  How can I create a general purpose AI that can analyze a movie script and extract concepts like characters, location, time, emotion etc so that we can use generative ai to generate storyboards, shot divisions, conceptual posters etc?
#
# 70:  Can AI kill MBA jobs even if MBA is done from Ivy league universities? What should one pursue AI/ML from IIT or MBA from IIM in terms of better opportunities/wealth and career growth/duration?
#
# 71:  What are some characteristics of good non-player character (NPC) artificial intelligence (AI) in video games?
#
# 72:  What is an AI chatbot, and how do AI chatbots work? How can I get the AI chat bot to write the Bible and Koran?
#
# 73:  How do I change my hairstyle naturally with AI?
#
# 74:  Ok, so you loved the idea of running your own AI/LLM models locally and decided to give it a go. What are the key lessons you learned that you are willing to share?
#
# 75:  What role does artificial intelligence play in making virtual simulations more immersive and adaptive to user behavior?
#
# 76:  How do I change my hairstyle naturally with AI?
#
# 77:  How does artificial intelligence impact everyday life and work?
#
# 78:  How does SW Alliance integrate AI and economic modeling to predict market trends and enhance investment decision-making?
#
# 79:  How do you think AI-generated images of Kannada actors as Mahabharata characters will impact the film industry?
#
# 80:  How close to real are AI girlfriends now?
#
# 81:  Can you use AI for football predictions?
#
# 82:  Where’s the link for extracting teeth and facial features?
#
# 83:  Can we take the genetic data of the Humans for the last 10000 years and using that create a model using AI to predict the character, traits, abilities of the Humans from 10000 years ahead of now?
#
# 84:  Will AI replace programmers?
#
# 85:  What are the benefits of using AI in professional photography?
#
# 86:  What’s the most efficient method for real-time face matching in Flutter with Google ML Kit?
#
# 87:  How do self-driving cars learn to distinguish between real objects and their images?
#
# 88:  Do you think AI tools will be effective in combating the sale of counterfeit toys in the future? Why or why not?
#
# 89:  I am in my 2-2 semester of my BTech in AI and ML. I am willing to give the GATE 2027 an attempt. How do I start?

# %% [markdown]
# # 4. Exercise
#
#
# Scrape **all questions** on the page

# %%
# define an async function

async def scrape():
    
    async with async_playwright() as playwright:
        
        # with visible browser. Change headless=True make browser invisible
        browser = await playwright.firefox.launch(headless=False)
        
        # wait for the browser opens a new page and direct to the url
        page = await browser.new_page()
        await page.goto('https://www.quora.com/topic/Machine-Learning')
        
        # can wait for 50 seconds before timeout
        await page.wait_for_timeout(50)
        
        # obtain intial html content
        html = await page.content()
        
        # keep scrolling until "break"
        while True:
            
            await page.evaluate("window.scrollTo(0, document.body.scrollHeight);")
            
            # Wait for 5 second or longer for content to be loaded
            await asyncio.sleep(5)
            
            # Retrieve page content to check udpates
            updated_html = await page.content()
            
            print(f"length of html: {len(updated_html)}")
            
            # if no new content is loaded, stop scrolling
            if updated_html == html:
                break
            else:
                html = updated_html
        
        # query all elements by CSS selector
        all_questions = await page.query_selector_all('span.q-box.qu-userSelect--text')
        
        qs =[]
        for i, q in enumerate(all_questions):
            
            # query the span element under each question
            q = await q.query_selector('span')
            
            # get the text
            text = await q.inner_text()
            
            print(f"{i}:  {text}\n")
            
            qs.append(text)
        
        
        await browser.close()

# %%
# Execute the scrape function in Jupyter
await scrape()

# In commandline, you can start many asychronous coroutines by 
#asyncio.run(scrape())
#asyncio.run(scrape())
# Out:
# length of html: 372655
# length of html: 547833
# length of html: 722124
# length of html: 888158
# length of html: 937923
# length of html: 937923
# 0:  What is your opinion of DeepSeek vs other US LLMs in terms of intellectual capital, Nvidia, and the efficacy of export bans in the West vs China battleground?
#
# 1:  Why is everyone so obsessed with AI? What is it actually going to provide in the future?
#
# 2:  You can train any 8 year old kid to drive well. Why is it taking years and the full might of supercomputer AI to get a computer to do it?
#
# 3:  How do publishing platforms detect AI-generated content in books?
#
# 4:  How do Americans feel knowing about deep seek and chat GPT?
#
# 5:  Will AI replace programmers?
#
# 6:  What are the best sites for learning Data Science?
#
# 7:  What is the Candy AI app?
#
# 8:  Will AI replace programmers?
#
# 9:  How should software engineers prepare for the possibility of getting replaced by AI by 2025?
#
# 10:  What is the best AI image generator?
#
# 11:  How do I change my hairstyle naturally with AI?
#
# 12:  Are AIs prone to being fearful and therefore wanting to own firearms like many fearful American humans?
#
# 13:  How does 'unfiltered AI' differ from regular AI?
#
# 14:  Can the AI adapt to user behavior over time?
#
# 15:  Will the startup Chinese AI engine DeepSeek overtake ChatGPT?
#
# 16:  How do I re detect faces in Google photos?
#
# 17:  What are examples of AI rewriting the Bible?
#
# 18:  How well does X's Grok summarize your contribution if you frequently use X (formerly Twitter)?
#
# 19:  Can the AI adapt to user behavior over time?
#
# 20:  Why do AI-generated images have bad text and faces?
#
# 21:  Do programmers, programming, machine learning, neural networks, artificial intelligence or robotics love wild animals, domestic animals, cats, kittens, dogs, puppies, etc.?
#
# 22:  Is OpenAI's new model O3 approaching AGI?
#
# 23:  What are some commonly used deep learning models? Which one would you suggest for someone new to deep neural networks (DNNs)?
#
# 24:  How quickly will humans run out of human-generated data to train AI models like ChatGPT?
#
# 25:  What are the best books about data science?
#
# 26:  The US has Chatgpt, Meta AI, and Gemini. China has Deepseek AI. What does India have in the AI field, or where do we Indians realistically stand as of today?
#
# 27:  Can an AI generate a side view of a person's face when given a photo of said person's face?
#
# 28:  How can the PiDog robot dog learn to recognize faces?
#
# 29:  Is there an AI tool that can help you to predict games accurately?
#
# 30:  What do you think Lyrak's AI engine—as well as user-generated AI characters—will look like when they launch in May?
#
# 31:  Why are Chinese characters so ugly and primitive? Can you read 50,000 ugly characters? Did AI generate the Chinese characters?
#
# 32:  Why is it considered an offense to train an artificial intelligence on the output of another AI? If something is published, can anyone then read it?
#
# 33:  What are the benefits of using AI in video editing?
#
# 34:  What is artificial intelligence?
#
# 35:  How do natural language processing models like BERT handle data that contains words from multiple languages?
#
# 36:  How can AI algorithms create game scenarios and characters, potentially replacing human game developers in certain aspects of game creation?
#
# 37:  What role does artificial intelligence play in making virtual simulations more immersive and adaptive to user behavior?
#
# 38:  What is optical character recognition? What is its relationship to convolutional neural networks (CNNs) in machine learning and artificial intelligence (AI)?
#
# 39:  How can I publish a high-quality machine learning paper with real innovation? Using only XGBoost for predictions feels too basic. How can I make my work stand out for a high impact journal?
#
# 40:  How well does X's Grok summarize your contribution if you frequently use X (formerly Twitter)?
#
# 41:  Are highly expensive Nvidia AI chips doomed after the release of highly cheap, efficient and open source Chinese Deepseek AI models?
#
# 42:  How can I pass an exam with valid Professional-Machine-Learning-engineer PDF dumps?
#
# 43:  How can generative adversarial networks (GANs) be countered using HPC?
#
# 44:  How do you think DeepSeek's AI reasoning model R1, which was published fully open-source and sparked a sell-off in US tech stocks, will impact the AI industry?
#
# 45:  Is it possible for AI to become so advanced that it becomes difficult to distinguish between real people and computer-generated characters in media? If so, when do experts predict this may happen?
#
# 46:  What is the number of parameters in a transformer-based language model like BERT or T5?
#
# 47:  Is it possible to easily identify AI profiles accurately on Instagram and Facebook without any annotation whatsoever?
#
# 48:  What role does artificial intelligence play in making virtual simulations more immersive and adaptive to user behavior?
#
# 49:  Is there an app that can detect your age from your face (facial recognition)?
#
# 50:  The US has Chatgpt, Meta AI, and Gemini. China has Deepseek AI. What does India have in the AI field, or where do we Indians realistically stand as of today?
#
# 51:  What does AI code look like?
#
# 52:  Do programmers, programming, machine learning, neural networks, artificial intelligence or robotics love wild animals, domestic animals, cats, kittens, dogs, puppies, etc.?
#
# 53:  What are the best sites for learning Data Science?
#
# 54:  Do programmers, programming, machine learning, neural networks, artificial intelligence or robotics love wild animals, domestic animals, cats, kittens, dogs, puppies, etc.?
#
# 55:  How do you think the ability to create user-generated AI characters for calls can enhance language learning and interview practice?
#
# 56:  How do I learn machine learning?
#
# 57:  Why is it considered an offense to train an artificial intelligence on the output of another AI? If something is published, can anyone then read it?
#
# 58:  Is it possible to illustrate entire novels/book series (such as The Lord Of The Rings and the Harry Potter books) using AI text-to-image generators such as Midjourney, with default image parameters set for all characters and sceneries in these books?
#
# 59:  With so many chips being described as "AI hardware" these days, would they be any good for creating better more realistic in-game characters, or are they merely for ChatGPT-like chatbots?
#
# 60:  How can AI-powered SaaS platforms predict user behavior?
#
# 61:  What are examples of AI rewriting the Bible?
#
# 62:  Is it possible to create video game characters that think and feel with AI?
#
# 63:  Which AI models are most effective at generating lifelike characters in storytelling?
#
# 64:  What are the best model, steps and simulator for AI for creating photorealistic human photos? I am now using Euler with Juggernaut model on image to do character to image.
#
# 65:  How can I create a general purpose AI that can analyze a movie script and extract concepts like characters, location, time, emotion etc so that we can use generative ai to generate storyboards, shot divisions, conceptual posters etc?
#
# 66:  What are some characteristics of good non-player character (NPC) artificial intelligence (AI) in video games?
#
# 67:  What is an AI chatbot, and how do AI chatbots work? How can I get the AI chat bot to write the Bible and Koran?
#
# 68:  How do I change my hairstyle naturally with AI?
#
# 69:  Ok, so you loved the idea of running your own AI/LLM models locally and decided to give it a go. What are the key lessons you learned that you are willing to share?
#
# 70:  What role does artificial intelligence play in making virtual simulations more immersive and adaptive to user behavior?
#
# 71:  How do I change my hairstyle naturally with AI?
#
# 72:  How does artificial intelligence impact everyday life and work?
#
# 73:  How does SW Alliance integrate AI and economic modeling to predict market trends and enhance investment decision-making?
#
# 74:  How do you think AI-generated images of Kannada actors as Mahabharata characters will impact the film industry?
#
# 75:  Can you use AI for football predictions?
#
# 76:  Where’s the link for extracting teeth and facial features?
#
# 77:  Can we take the genetic data of the Humans for the last 10000 years and using that create a model using AI to predict the character, traits, abilities of the Humans from 10000 years ahead of now?
#
# 78:  Will AI replace programmers?
#
# 79:  What are the benefits of using AI in professional photography?
#
# 80:  How do self-driving cars learn to distinguish between real objects and their images?
#
# 81:  What’s the most efficient method for real-time face matching in Flutter with Google ML Kit?
#
# 82:  Do you think AI tools will be effective in combating the sale of counterfeit toys in the future? Why or why not?
#
# 83:  I am in my 2-2 semester of my BTech in AI and ML. I am willing to give the GATE 2027 an attempt. How do I start?
#
# 84:  How does Gemini compare to OpenAI's GPT-4?
#
# 85:  What would happen if you matched 2 advanced AIS played against each other on the game of League of Legends with the same character?
